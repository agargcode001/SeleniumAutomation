# %%
import pandas as pd
from alpha_vantage.timeseries import TimeSeries
import time
import xlsxwriter

# Reading the raw data file to get the token name
import pandas as pd
df = pd.read_excel('raw_data.xlsx')
df
# Out:
#      Unnamed: 0  Unnamed: 0.1    Unnamed: 1  \
# 0             0           NaN  Stock Symbol
# 1             1           NaN          SBIN
# 2             2           NaN    BANKBARODA
# 3             3           NaN           PNB
# 4             4           NaN      HDFCBANK
# 5             5           NaN     ICICIBANK
# 6             6           NaN      AXISBANK
# 7             7           NaN     KOTAKBANK
# 8             8           NaN    INDUSINDBK
# 9             9           NaN    FEDERALBNK
# 10           10           NaN    IDFCFIRSTB
# 11           11           NaN       RBLBANK
# 12           12           NaN       YESBANK
# 13           13           NaN         CANBK
# 14           14           NaN           ACC
# 15           15           NaN      ADANIENT
# 16           16           NaN    ADANIPORTS
# 17           17           NaN    ADANIPOWER
# 18           18           NaN    AMARAJABAT
# 19           19           NaN     AMBUJACEM
# ...

# %%
# Modifying the dataframe to only retain token values
tickers = df.iloc[1:148,2:3]
tickers
# Out:
#      Unnamed: 1
# 1          SBIN
# 2    BANKBARODA
# 3           PNB
# 4      HDFCBANK
# 5     ICICIBANK
# 6      AXISBANK
# 7     KOTAKBANK
# 8    INDUSINDBK
# 9    FEDERALBNK
# 10   IDFCFIRSTB
# 11      RBLBANK
# 12      YESBANK
# 13        CANBK
# 14          ACC
# 15     ADANIENT
# 16   ADANIPORTS
# 17   ADANIPOWER
# 18   AMARAJABAT
# 19    AMBUJACEM
# 20   APOLLOHOSP
# 21   APOLLOTYRE
# 22     ASHOKLEY
# 23   ASIANPAINT
# 24   AUROPHARMA
# 25   BAJAJ-AUTO
# 26   BAJAJFINSV
# 27   BAJFINANCE
# 28   BALKRISIND
# 29    BATAINDIA
# 30          BEL
# ..          ...
# 118     SIEMENS
# 119         SRF
# 120  SRTRANSFIN
# 121   SUNPHARMA
# 122       SUNTV
# 123    TATACHEM
# 124  TATAGLOBAL
# 125  TATAMOTORS
# 126  TATAMTRDVR
# 127   TATAPOWER
# 128   TATASTEEL
# 129         TCS
# 130       TECHM
# 131       TITAN
# 132  TORNTPHARM
# 133  TORNTPOWER
# 134    TVSMOTOR
# 135         UBL
# 136     UJJIVAN
# 137  ULTRACEMCO
# 138         UPL
# 139        VEDL
# 140      VOLTAS
# ...

# %%
# Convert dataframe to list having multiple lists and then converting them into a single list of symbols(str format)
tickers = tickers.values.tolist()
tokens = []
for i in range(len(tickers)):
    tokens.append(tickers[i][0])
tokens
# Out:
# ['SBIN',
#  'BANKBARODA',
#  'PNB',
#  'HDFCBANK',
#  'ICICIBANK',
#  'AXISBANK',
#  'KOTAKBANK',
#  'INDUSINDBK',
#  'FEDERALBNK',
#  'IDFCFIRSTB',
#  'RBLBANK',
#  'YESBANK',
#  'CANBK',
#  'ACC',
#  'ADANIENT',
#  'ADANIPORTS',
#  'ADANIPOWER',
#  'AMARAJABAT',
#  'AMBUJACEM',
#  'APOLLOHOSP',
#  'APOLLOTYRE',
#  'ASHOKLEY',
#  'ASIANPAINT',
#  'AUROPHARMA',
#  'BAJAJ-AUTO',
#  'BAJAJFINSV',
#  'BAJFINANCE',
#  'BALKRISIND',
#  'BATAINDIA',
#  'BEL',
#  'BERGEPAINT',
#  'BHARATFORG',
#  'BHARTIARTL',
#  'BHEL',
#  'BIOCON',
#  'BOSCHLTD',
#  'BPCL',
#  'BRITANNIA',
#  'CADILAHC',
#  'CASTROLIND',
#  'CENTURYTEX',
#  'CESC',
#  'CHOLAFIN',
#  'CIPLA',
#  'COALINDIA',
#  'COLPAL',
#  'CONCOR',
#  'CUMMINSIND',
#  'DABUR',
#  'DISHTV',
#  'DIVISLAB',
#  'DLF',
#  'DRREDDY',
#  'EICHERMOT',
#  'EQUITAS',
#  'ESCORTS',
#  'EXIDEIND',
#  'GAIL',
#  'GLENMARK',
#  'GMRINFRA',
#  'GODREJCP',
#  'GRASIM',
#  'HAVELLS',
#  'HCLTECH',
#  'HDFC',
#  'HEROMOTOCO',
#  'HINDALCO',
# ...

# %%
# Add .NS to every string into the list
for i in range(len(tokens)):
    tokens[i] += '.NS'
tokens
# Out:
# ['SBIN.NS',
#  'BANKBARODA.NS',
#  'PNB.NS',
#  'HDFCBANK.NS',
#  'ICICIBANK.NS',
#  'AXISBANK.NS',
#  'KOTAKBANK.NS',
#  'INDUSINDBK.NS',
#  'FEDERALBNK.NS',
#  'IDFCFIRSTB.NS',
#  'RBLBANK.NS',
#  'YESBANK.NS',
#  'CANBK.NS',
#  'ACC.NS',
#  'ADANIENT.NS',
#  'ADANIPORTS.NS',
#  'ADANIPOWER.NS',
#  'AMARAJABAT.NS',
#  'AMBUJACEM.NS',
#  'APOLLOHOSP.NS',
#  'APOLLOTYRE.NS',
#  'ASHOKLEY.NS',
#  'ASIANPAINT.NS',
#  'AUROPHARMA.NS',
#  'BAJAJ-AUTO.NS',
#  'BAJAJFINSV.NS',
#  'BAJFINANCE.NS',
#  'BALKRISIND.NS',
#  'BATAINDIA.NS',
#  'BEL.NS',
#  'BERGEPAINT.NS',
#  'BHARATFORG.NS',
#  'BHARTIARTL.NS',
#  'BHEL.NS',
#  'BIOCON.NS',
#  'BOSCHLTD.NS',
#  'BPCL.NS',
#  'BRITANNIA.NS',
#  'CADILAHC.NS',
#  'CASTROLIND.NS',
#  'CENTURYTEX.NS',
#  'CESC.NS',
#  'CHOLAFIN.NS',
#  'CIPLA.NS',
#  'COALINDIA.NS',
#  'COLPAL.NS',
#  'CONCOR.NS',
#  'CUMMINSIND.NS',
#  'DABUR.NS',
#  'DISHTV.NS',
#  'DIVISLAB.NS',
#  'DLF.NS',
#  'DRREDDY.NS',
#  'EICHERMOT.NS',
#  'EQUITAS.NS',
#  'ESCORTS.NS',
# ...

# %%
test = []
i=0
while i < 5:
    test.append(tokens[i])
    i += 1
test
# Out:
# ['SBIN.NS', 'BANKBARODA.NS', 'PNB.NS', 'HDFCBANK.NS', 'ICICIBANK.NS']

# %%
#Enter your uniquely generated api key
api_key = open("key.txt", 'r').read()
test
api_key
ts = TimeSeries(key = api_key, output_format = 'pandas')
api_key
# Out:
# 'U4HYA921OFBGKOEN'

# %%
#Initialise a list of dataframes
df_list = []
df_summary = []

#Writing to an exisitng excel named as 'output.xlsx'
writer = pd.ExcelWriter('output.xlsx')

# Fetching data for different stocks and writing it to excel file
for i, tst in enumerate(test):
    data, meta_data =  ts.get_intraday(symbol = tst, interval = '5min', outputsize='full')
    data.to_excel(writer,tst)
    
#     df_list.append(data)
#     df_summary.append(meta_data)
writer.save()

# %%
meta_data
# Out:
# {'1. Information': 'Intraday (5min) open, high, low, close prices and volume',
#  '2. Symbol': 'ICICIBANK.NS',
#  '3. Last Refreshed': '2020-04-20 05:55:00',
#  '4. Interval': '5min',
#  '5. Output Size': 'Full size',
#  '6. Time Zone': 'US/Eastern'}
